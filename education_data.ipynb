# %% [markdown]
# # **Education statistics analysis**

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load dataset

# %%
# Load test and train data
df_raw = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRroHoTWTrXGNoYReMfwgDvaO7Jm_vgIlBR-bvGhOsMpl0h4vo65LFy00EjaMIpNSF9oo6mQtMoWgKi/pub?gid=2021103384&single=true&output=csv")

print(f"shape of train data: {df_raw.shape}")
# Out:
# shape of train data: (44, 11)

# %%
df_raw.head()
# Out:
#    Year Government expenditure per primary student as % of GDP per capita (%)  \
# 0  1971                                                 ..
# 1  1972                                                 ..
# 2  1973                                                 ..
# 3  1974                                                 ..
# 4  1975                                                 ..
#
#   Government expenditure per secondary student as % of GDP per capita (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Government expenditure per tertiary student as % of GDP per capita (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Expenditure on education as % of total government expenditure (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Expenditure on primary as % of government expenditure on education (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Expenditure on secondary as % of government expenditure on education (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Expenditure on tertiary as % of government expenditure on education (%)  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                                 ..
# 4                                                 ..
#
#   Adjusted savings: education expenditure (% of GNI)  \
# 0                                                2.6
# 1                                                2.4
# 2                                                2.6
# 3                                                2.3
# 4                                                2.5
#
#   Adjusted savings: education expenditure (current US$)  \
# 0                                        353795485.6
# 1                                        413797828.6
# 2                                        709653901.1
# 3                                         1097398800
# 4                                         1315823067
#
#   Government expenditure on education as % of GDP (%)
# 0                                               2.87
# 1                                               2.88
# 2                                               3.02
# 3                                               2.83
# 4                                               3.09

# %%
df_raw.tail()
# Out:
#     Year  \
# 39  2010
# 40  2011
# 41  2012
# 42  2013
# 43  2014
#
#    Government expenditure per primary student as % of GDP per capita (%)  \
# 39                                              13.73
# 40                                              14.45
# 41                                              11.04
# 42                                               8.45
# 43                                               8.53
#
#    Government expenditure per secondary student as % of GDP per capita (%)  \
# 39                                              20.97
# 40                                              16.37
# 41                                              14.53
# 42                                              19.56
# 43                                              16.16
#
#    Government expenditure per tertiary student as % of GDP per capita (%)  \
# 39                                              17.65
# 40                                              19.95
# 41                                              15.67
# 42                                              13.31
# 43                                              14.33
#
#    Expenditure on education as % of total government expenditure (%)  \
# 39                                               18.8
# 40                                              19.13
# 41                                              17.03
# 42                                              21.67
# 43                                              19.67
#
#    Expenditure on primary as % of government expenditure on education (%)  \
# 39                                              24.68
# 40                                              27.21
# 41                                              25.41
# 42                                              26.21
# 43                                              26.76
#
#    Expenditure on secondary as % of government expenditure on education (%)  \
# 39                                              49.18
# 40                                              39.28
# 41                                              41.43
# 42                                               45.3
# 43                                              39.48
#
#    Expenditure on tertiary as % of government expenditure on education (%)  \
# 39                                              21.36
# 40                                              27.23
# 41                                              27.63
# 42                                              22.94
# 43                                              28.31
#
#    Adjusted savings: education expenditure (% of GNI)  \
# 39                                               4.11
# 40                                               3.67
# 41                                               3.22
# 42                                               3.16
# 43                                                 ..
#
#    Adjusted savings: education expenditure (current US$)  \
# 39                                        19229457000
# 40                                        21704376118
# 41                                        18967301164
# 42                                        16206091600
# 43                                                 ..
#
#    Government expenditure on education as % of GDP (%)
# 39                                               4.26
# 40                                               4.05
# 41                                               3.31
# 42                                               3.32
# 43                                               3.06

# %% [markdown]
# ### Exploratory data analysis

# %%
df = df_raw.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Year                                                                      44 non-null     int64
#  1   Government expenditure per primary student as % of GDP per capita (%)     44 non-null     object
#  2   Government expenditure per secondary student as % of GDP per capita (%)   44 non-null     object
#  3   Government expenditure per tertiary student as % of GDP per capita (%)    44 non-null     object
#  4   Expenditure on education as % of total government expenditure (%)         44 non-null     object
#  5   Expenditure on primary as % of government expenditure on education (%)    44 non-null     object
#  6   Expenditure on secondary as % of government expenditure on education (%)  44 non-null     object
#  7   Expenditure on tertiary as % of government expenditure on education (%)   44 non-null     object
#  8   Adjusted savings: education expenditure (% of GNI)                        44 non-null     object
#  9   Adjusted savings: education expenditure (current US$)                     44 non-null     object
#  10  Government expenditure on education as % of GDP (%)                       44 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 3.9+ KB

# %%
df.describe()
# Out:
#               Year
# count    44.000000
# mean   1992.500000
# std      12.845233
# min    1971.000000
# 25%    1981.750000
# 50%    1992.500000
# 75%    2003.250000
# max    2014.000000

# %%
# df=df.replace('..',0)
df=df.replace('..',np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Year                                                                      44 non-null     int64
#  1   Government expenditure per primary student as % of GDP per capita (%)     14 non-null     object
#  2   Government expenditure per secondary student as % of GDP per capita (%)   14 non-null     object
#  3   Government expenditure per tertiary student as % of GDP per capita (%)    14 non-null     object
#  4   Expenditure on education as % of total government expenditure (%)         16 non-null     object
#  5   Expenditure on primary as % of government expenditure on education (%)    14 non-null     object
#  6   Expenditure on secondary as % of government expenditure on education (%)  14 non-null     object
#  7   Expenditure on tertiary as % of government expenditure on education (%)   14 non-null     object
#  8   Adjusted savings: education expenditure (% of GNI)                        41 non-null     object
#  9   Adjusted savings: education expenditure (current US$)                     41 non-null     object
#  10  Government expenditure on education as % of GDP (%)                       37 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 3.9+ KB

# %%
objVar = []
for var in df.columns:
    if(df[var].dtypes=='object'):
      objVar.append(var)
print(objVar)
# Out:
# ['Government expenditure per primary student as % of GDP per capita (%)', 'Government expenditure per secondary student as % of GDP per capita (%)', 'Government expenditure per tertiary student as % of GDP per capita (%)', 'Expenditure on education as % of total government expenditure (%)', 'Expenditure on primary as % of government expenditure on education (%)', 'Expenditure on secondary as % of government expenditure on education (%)', 'Expenditure on tertiary as % of government expenditure on education (%)', 'Adjusted savings: education expenditure (% of GNI)', 'Adjusted savings: education expenditure (current US$)', 'Government expenditure on education as % of GDP (%)']

# %%
for var in objVar:
  df[var]=df[var].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 11 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Year                                                                      44 non-null     int64
#  1   Government expenditure per primary student as % of GDP per capita (%)     14 non-null     float64
#  2   Government expenditure per secondary student as % of GDP per capita (%)   14 non-null     float64
#  3   Government expenditure per tertiary student as % of GDP per capita (%)    14 non-null     float64
#  4   Expenditure on education as % of total government expenditure (%)         16 non-null     float64
#  5   Expenditure on primary as % of government expenditure on education (%)    14 non-null     float64
#  6   Expenditure on secondary as % of government expenditure on education (%)  14 non-null     float64
#  7   Expenditure on tertiary as % of government expenditure on education (%)   14 non-null     float64
#  8   Adjusted savings: education expenditure (% of GNI)                        41 non-null     float64
#  9   Adjusted savings: education expenditure (current US$)                     41 non-null     float64
#  10  Government expenditure on education as % of GDP (%)                       37 non-null     float64
# dtypes: float64(10), int64(1)
# memory usage: 3.9 KB

# %%
df.head()
# Out:
#    Year  \
# 0  1971
# 1  1972
# 2  1973
# 3  1974
# 4  1975
#
#    Government expenditure per primary student as % of GDP per capita (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure per secondary student as % of GDP per capita (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Government expenditure per tertiary student as % of GDP per capita (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Expenditure on education as % of total government expenditure (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Expenditure on primary as % of government expenditure on education (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Expenditure on secondary as % of government expenditure on education (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Expenditure on tertiary as % of government expenditure on education (%)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Adjusted savings: education expenditure (% of GNI)  \
# 0                                                2.6
# 1                                                2.4
# 2                                                2.6
# 3                                                2.3
# 4                                                2.5
#
#    Adjusted savings: education expenditure (current US$)  \
# 0                                       3.537955e+08
# 1                                       4.137978e+08
# 2                                       7.096539e+08
# 3                                       1.097399e+09
# 4                                       1.315823e+09
#
#    Government expenditure on education as % of GDP (%)
# 0                                               2.87
# 1                                               2.88
# 2                                               3.02
# 3                                               2.83
# 4                                               3.09

# %%
df.describe()
# Out:
#               Year  \
# count    44.000000
# mean   1992.500000
# std      12.845233
# min    1971.000000
# 25%    1981.750000
# 50%    1992.500000
# 75%    2003.250000
# max    2014.000000
#
#        Government expenditure per primary student as % of GDP per capita (%)  \
# count                                          14.000000
# mean                                           12.580714
# std                                             2.919688
# min                                             8.450000
# 25%                                            11.090000
# 50%                                            11.755000
# 75%                                            14.445000
# max                                            17.630000
#
#        Government expenditure per secondary student as % of GDP per capita (%)  \
# count                                          14.000000
# mean                                           16.152857
# std                                             3.777994
# min                                            10.180000
# 25%                                            12.555000
# 50%                                            16.265000
# 75%                                            19.445000
# max                                            20.970000
#
#        Government expenditure per tertiary student as % of GDP per capita (%)  \
# count                                          14.000000
# mean                                           23.965714
# std                                             8.072030
# min                                            13.310000
# 25%                                            18.110000
# 50%                                            22.465000
# 75%                                            29.535000
# max                                            38.830000
#
#        Expenditure on education as % of total government expenditure (%)  \
# count                                          16.000000
# mean                                           20.690625
# std                                             2.327524
# min                                            17.030000
# 25%                                            19.295000
# 50%                                            20.345000
# 75%                                            21.655000
# max                                            26.330000
#
#        Expenditure on primary as % of government expenditure on education (%)  \
# count                                          14.000000
# mean                                           25.872143
# std                                             1.844519
# min                                            22.440000
# 25%                                            24.862500
# 50%                                            25.870000
# 75%                                            27.097500
# max                                            28.670000
#
#        Expenditure on secondary as % of government expenditure on education (%)  \
# count                                          14.000000
# mean                                           41.831429
# std                                             5.893065
# min                                            34.620000
# 25%                                            36.090000
# 50%                                            40.455000
# 75%                                            47.832500
# max                                            49.410000
#
#        Expenditure on tertiary as % of government expenditure on education (%)  \
# count                                          14.000000
# mean                                           21.219286
# std                                             4.169736
# min                                            15.360000
# 25%                                            18.690000
# 50%                                            20.635000
# 75%                                            22.712500
# max                                            28.310000
#
#        Adjusted savings: education expenditure (% of GNI)  \
# count                                          41.000000
# mean                                            4.082439
# std                                             1.173362
# min                                             2.300000
# 25%                                             3.300000
# 50%                                             4.000000
# 75%                                             4.510000
# max                                             6.600000
#
#        Adjusted savings: education expenditure (current US$)  \
# count                                       4.100000e+01
# mean                                        7.030096e+09
# std                                         5.451025e+09
# min                                         3.537955e+08
# 25%                                         4.162111e+09
# 50%                                         5.649226e+09
# 75%                                         7.072692e+09
# max                                         2.170438e+10
#
#        Government expenditure on education as % of GDP (%)
# count                                          37.000000
# mean                                            4.233514
# std                                             0.942945
# min                                             2.830000
# 25%                                             3.760000
# 50%                                             4.260000
# 75%                                             4.670000
# max                                             7.470000

# %%
sns.heatmap(df[df.columns].corr(),cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Data cleaning

# %%
df.isnull().sum()
# Out:
# Year                                                                         0
# Government expenditure per primary student as % of GDP per capita (%)       30
# Government expenditure per secondary student as % of GDP per capita (%)     30
# Government expenditure per tertiary student as % of GDP per capita (%)      30
# Expenditure on education as % of total government expenditure (%)           28
# Expenditure on primary as % of government expenditure on education (%)      30
# Expenditure on secondary as % of government expenditure on education (%)    30
# Expenditure on tertiary as % of government expenditure on education (%)     30
# Adjusted savings: education expenditure (% of GNI)                           3
# Adjusted savings: education expenditure (current US$)                        3
# Government expenditure on education as % of GDP (%)                          7
# dtype: int64

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull().mean()*100
# Out:
# Year                                                                         0.000000
# Government expenditure per primary student as % of GDP per capita (%)       68.181818
# Government expenditure per secondary student as % of GDP per capita (%)     68.181818
# Government expenditure per tertiary student as % of GDP per capita (%)      68.181818
# Expenditure on education as % of total government expenditure (%)           63.636364
# Expenditure on primary as % of government expenditure on education (%)      68.181818
# Expenditure on secondary as % of government expenditure on education (%)    68.181818
# Expenditure on tertiary as % of government expenditure on education (%)     68.181818
# Adjusted savings: education expenditure (% of GNI)                           6.818182
# Adjusted savings: education expenditure (current US$)                        6.818182
# Government expenditure on education as % of GDP (%)                         15.909091
# dtype: float64

# %%
dropVar=[]
objVar = []
for var in df.columns:
    if(df[var].isnull().mean()*100>=50):
      dropVar.append(var)
print(dropVar)
# Out:
# ['Government expenditure per primary student as % of GDP per capita (%)', 'Government expenditure per secondary student as % of GDP per capita (%)', 'Government expenditure per tertiary student as % of GDP per capita (%)', 'Expenditure on education as % of total government expenditure (%)', 'Expenditure on primary as % of government expenditure on education (%)', 'Expenditure on secondary as % of government expenditure on education (%)', 'Expenditure on tertiary as % of government expenditure on education (%)']

# %%
df2=df.copy()
for var in dropVar:
  df2 = df2.drop(var, axis='columns')
df2
# Out:
#     Year  Adjusted savings: education expenditure (% of GNI)  \
# 0   1971                                               2.60
# 1   1972                                               2.40
# 2   1973                                               2.60
# 3   1974                                               2.30
# 4   1975                                               2.50
# 5   1976                                               6.60
# 6   1977                                               5.20
# 7   1978                                               6.60
# 8   1979                                               6.60
# 9   1980                                               6.60
# 10  1981                                               6.50
# 11  1982                                               5.20
# 12  1983                                               3.80
# 13  1984                                               3.50
# 14  1985                                               3.20
# 15  1986                                               3.30
# 16  1987                                               4.10
# 17  1988                                               3.50
# 18  1989                                               3.80
# 19  1990                                               3.50
# 20  1991                                                NaN
# 21  1992                                                NaN
# 22  1993                                               3.80
# 23  1994                                               4.00
# 24  1995                                               3.60
# 25  1996                                               3.20
# 26  1997                                               2.80
# 27  1998                                               4.16
# 28  1999                                               4.12
# 29  2000                                               4.01
# 30  2001                                               4.00
# 31  2002                                               4.52
# 32  2003                                               4.41
# 33  2004                                               4.54
# 34  2005                                               4.51
# 35  2006                                               4.77
# 36  2007                                               4.48
# 37  2008                                               3.86
# 38  2009                                               4.04
# 39  2010                                               4.11
# 40  2011                                               3.67
# 41  2012                                               3.22
# 42  2013                                               3.16
# 43  2014                                                NaN
#
#     Adjusted savings: education expenditure (current US$)  \
# 0                                        3.537955e+08
# 1                                        4.137978e+08
# 2                                        7.096539e+08
# 3                                        1.097399e+09
# 4                                        1.315823e+09
# 5                                        4.518486e+09
# 6                                        4.162111e+09
# 7                                        5.016654e+09
# 8                                        6.195902e+09
# 9                                        6.441730e+09
# 10                                       6.847165e+09
# 11                                       6.827704e+09
# 12                                       6.041354e+09
# 13                                       5.783645e+09
# 14                                       5.883424e+09
# 15                                       7.072692e+09
# 16                                       5.649226e+09
# 17                                       4.392150e+09
# 18                                       4.679662e+09
# 19                                       4.383470e+09
# 20                                                NaN
# 21                                                NaN
# 22                                       2.432668e+09
# 23                                       2.850653e+09
# 24                                       3.507195e+09
# 25                                       3.797440e+09
# 26                                       3.180072e+09
# 27                                       4.614049e+09
# 28                                       4.652840e+09
# 29                                       4.390228e+09
# 30                                       5.077000e+09
# 31                                       5.830303e+09
# 32                                       6.784035e+09
# 33                                       8.325861e+09
# 34                                       9.896564e+09
# 35                                       1.234271e+10
# 36                                       1.516162e+10
# 37                                       1.538384e+10
# 38                                       1.611378e+10
# 39                                       1.922946e+10
# 40                                       2.170438e+10
# 41                                       1.896730e+10
# 42                                       1.620609e+10
# 43                                                NaN
#
#     Government expenditure on education as % of GDP (%)
# 0                                                2.87
# 1                                                2.88
# 2                                                3.02
# 3                                                2.83
# 4                                                3.09
# 5                                                 NaN
# 6                                                5.79
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                               7.47
# 11                                               6.01
# 12                                               4.33
# 13                                               4.04
# 14                                               3.67
# 15                                               3.77
# 16                                               4.36
# 17                                               3.86
# 18                                               4.23
# 19                                               3.99
# 20                                               4.03
# 21                                               3.93
# 22                                               4.67
# 23                                                NaN
# 24                                               4.37
# 25                                               3.76
# 26                                                NaN
# 27                                                NaN
# 28                                               4.53
# 29                                               4.38
# 30                                               4.41
# 31                                               4.93
# 32                                               4.82
# 33                                               4.87
# 34                                               4.72
# 35                                               5.06
# 36                                               5.05
# 37                                               4.45
# 38                                               4.45
# 39                                               4.26
# 40                                               4.05
# 41                                               3.31
# 42                                               3.32
# 43                                               3.06

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 4 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Year                                                   44 non-null     int64
#  1   Adjusted savings: education expenditure (% of GNI)     41 non-null     float64
#  2   Adjusted savings: education expenditure (current US$)  41 non-null     float64
#  3   Government expenditure on education as % of GDP (%)    37 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 1.5 KB

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df2.isnull())
# Out:
# <AxesSubplot:>

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer = imputer.fit(df2)
  
X = imputer.transform(df2)
df3 = pd.DataFrame(X, columns = df2.columns)
df3
# Out:
#       Year  Adjusted savings: education expenditure (% of GNI)  \
# 0   1971.0                                           2.600000
# 1   1972.0                                           2.400000
# 2   1973.0                                           2.600000
# 3   1974.0                                           2.300000
# 4   1975.0                                           2.500000
# 5   1976.0                                           6.600000
# 6   1977.0                                           5.200000
# 7   1978.0                                           6.600000
# 8   1979.0                                           6.600000
# 9   1980.0                                           6.600000
# 10  1981.0                                           6.500000
# 2                                            3.020000
# 3                                            2.830000
# 4                                            3.090000
# 5                                            4.233514
# 6                                            5.790000
# 7                                            4.233514
# 8                                            4.233514
# 9                                            4.233514
# 10                                           7.470000
# 11                                           6.010000
# 12                                           4.330000
# 13                                           4.040000
# 14                                           3.670000
# 15                                           3.770000
# 16                                           4.360000
# 17                                           3.860000
# 18                                           4.230000
# 19                                           3.990000
# 20                                           4.030000
# 21                                           3.930000
# 22                                           4.670000
# 23                                           4.233514
# 24                                           4.370000
# 25                                           3.760000
# 26                                           4.233514
# 27                                           4.233514
# 28                                           4.530000
# 29                                           4.380000
# 30                                           4.410000
# 31                                           4.930000
# 32                                           4.820000
# 33                                           4.870000
# 34                                           4.720000
# 35                                           5.060000
# 36                                           5.050000
# 37                                           4.450000
# 38                                           4.450000
# 39                                           4.260000
# 40                                           4.050000
# 41                                           3.310000
# 42                                           3.320000
# 43                                           3.060000

# %%
plt.figure(figsize=(16,9))
for i,var in enumerate(df4.columns):
  plt.subplot(3,2,i+1)
  sns.boxplot(df4[var])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
drop_index=df4[ (df4['Government expenditure on education as % of GDP (%)']<3.15) ].index
df4.drop(drop_index, inplace=True)
drop_index=df4[ (df4['Government expenditure on education as % of GDP (%)']>5) ].index
df4.drop(drop_index, inplace=True)
drop_index=df4[ (df4['Adjusted savings: education expenditure (% of GNI)']>6) ].index
df4.drop(drop_index, inplace=True)
drop_index=df4[ (df4['Adjusted savings: education expenditure (% of GNI)']<2.75) ].index
df4.drop(drop_index, inplace=True)
drop_index=df4[ (df4['Adjusted savings: education expenditure (current US$)']>0.85e+10) ].index
df4.drop(drop_index, inplace=True)
df4
# Out:
#       Year  Adjusted savings: education expenditure (% of GNI)  \
# 12  1983.0                                           3.800000
# 13  1984.0                                           3.500000
# 14  1985.0                                           3.200000
# 15  1986.0                                           3.300000
# 16  1987.0                                           4.100000
# 17  1988.0                                           3.500000
# 18  1989.0                                           3.800000
# 19  1990.0                                           3.500000
# 20  1991.0                                           4.082439
# 21  1992.0                                           4.082439
# 22  1993.0                                           3.800000
# 23  1994.0                                           4.000000
# 24  1995.0                                           3.600000
# 25  1996.0                                           3.200000
# 26  1997.0                                           2.800000
# 27  1998.0                                           4.160000
# 28  1999.0                                           4.120000
# 29  2000.0                                           4.010000
# 30  2001.0                                           4.000000
# 31  2002.0                                           4.520000
# 32  2003.0                                           4.410000
# 33  2004.0                                           4.540000
#
#     Adjusted savings: education expenditure (current US$)  \
# 12                                       6.041354e+09
# 13                                       5.783645e+09
# 14                                       5.883424e+09
# 15                                       7.072692e+09
# 16                                       5.649226e+09
# 17                                       4.392150e+09
# 18                                       4.679662e+09
# 19                                       4.383470e+09
# 20                                       7.030096e+09
# 21                                       7.030096e+09
# 22                                       2.432668e+09
# 23                                       2.850653e+09
# 24                                       3.507195e+09
# 25                                       3.797440e+09
# 26                                       3.180072e+09
# 27                                       4.614049e+09
# 28                                       4.652840e+09
# 29                                       4.390228e+09
# 30                                       5.077000e+09
# 31                                       5.830303e+09
# 32                                       6.784035e+09
# 33                                       8.325861e+09
#
#     Government expenditure on education as % of GDP (%)
# 12                                           4.330000
# 13                                           4.040000
# 14                                           3.670000
# 15                                           3.770000
# 16                                           4.360000
# 17                                           3.860000
# 18                                           4.230000
# 19                                           3.990000
# 20                                           4.030000
# 21                                           3.930000
# 22                                           4.670000
# 23                                           4.233514
# 24                                           4.370000
# 25                                           3.760000
# 26                                           4.233514
# 27                                           4.233514
# 28                                           4.530000
# 29                                           4.380000
# 30                                           4.410000
# 31                                           4.930000
# 32                                           4.820000
# 33                                           4.870000

# %%
plt.figure(figsize=(16,9))
for i,var in enumerate(df4.columns):
  plt.subplot(3,2,i+1)
  sns.boxplot(df4[var])
# Out:
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df4 = df4.reset_index(drop=True)
df4
# Out:
#       Year  Adjusted savings: education expenditure (% of GNI)  \
# 0   1983.0                                           3.800000
# 1   1984.0                                           3.500000
# 2   1985.0                                           3.200000
# 3   1986.0                                           3.300000
# 4   1987.0                                           4.100000
# 5   1988.0                                           3.500000
# 6   1989.0                                           3.800000
# 7   1990.0                                           3.500000
# 8   1991.0                                           4.082439
# 9   1992.0                                           4.082439
# 10  1993.0                                           3.800000
# 11  1994.0                                           4.000000
# 12  1995.0                                           3.600000
# 13  1996.0                                           3.200000
# 14  1997.0                                           2.800000
# 15  1998.0                                           4.160000
# 16  1999.0                                           4.120000
# 17  2000.0                                           4.010000
# 18  2001.0                                           4.000000
# 19  2002.0                                           4.520000
# 20  2003.0                                           4.410000
# 21  2004.0                                           4.540000
#
#     Adjusted savings: education expenditure (current US$)  \
# 0                                        6.041354e+09
# 1                                        5.783645e+09
# 2                                        5.883424e+09
# 3                                        7.072692e+09
# 4                                        5.649226e+09
# 5                                        4.392150e+09
# 6                                        4.679662e+09
# 7                                        4.383470e+09
# 8                                        7.030096e+09
# 9                                        7.030096e+09
# 10                                       2.432668e+09
# 11                                       2.850653e+09
# 12                                       3.507195e+09
# 13                                       3.797440e+09
# 14                                       3.180072e+09
# 15                                       4.614049e+09
# 16                                       4.652840e+09
# 17                                       4.390228e+09
# 18                                       5.077000e+09
# 19                                       5.830303e+09
# 20                                       6.784035e+09
# 21                                       8.325861e+09
#
#     Government expenditure on education as % of GDP (%)
# 0                                            4.330000
# 1                                            4.040000
# 2                                            3.670000
# 3                                            3.770000
# 4                                            4.360000
# 5                                            3.860000
# 6                                            4.230000
# 7                                            3.990000
# 8                                            4.030000
# 9                                            3.930000
# 10                                           4.670000
# 11                                           4.233514
# 12                                           4.370000
# 13                                           3.760000
# 14                                           4.233514
# 15                                           4.233514
# 16                                           4.530000
# 17                                           4.380000
# 18                                           4.410000
# 19                                           4.930000
# 20                                           4.820000
# 21                                           4.870000

# %%
sns.heatmap(df4[df4.columns].corr(),cmap="coolwarm", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Train Test split

# %%
y = df4['Government expenditure on education as % of GDP (%)']
X = df4.drop("Government expenditure on education as % of GDP (%)", axis=1)
print('Shape of X = ', X.shape)
print('Shape of y = ', y.shape)
 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 51)
print('Shape of X_train = ', X_train.shape)
print('Shape of y_train = ', y_train.shape)
print('Shape of X_test = ', X_test.shape)
print('Shape of y_test = ', y_test.shape)
# Out:
# Shape of X =  (22, 3)
# Shape of y =  (22,)
# Shape of X_train =  (17, 3)
# Shape of y_train =  (17,)
# Shape of X_test =  (5, 3)
# Shape of y_test =  (5,)

# %% [markdown]
# ### Feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X_train= sc.transform(X_train)
X_test = sc.transform(X_test)
